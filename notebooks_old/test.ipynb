# %%
import gc_utils
import h5py
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
sim = "m12b"
sim_dir = "/Users/z5114326/Documents/simulations/"

ghost_file = sim_dir + sim + "/" + sim + "_ghosts.hdf5"
ghost_data = h5py.File(ghost_file, "r")  # open processed data file

# %%
ghost_data.keys()
# Out:
# <KeysViewHDF5 ['it000', 'it001', 'it002', 'it003', 'it004', 'it005', 'it006', 'it007', 'it008', 'it009', 'it010', 'it011', 'it012', 'it013', 'it014', 'it015', 'it016', 'it017', 'it018', 'it019', 'it020', 'it021', 'it022', 'it023', 'it024', 'it025', 'it026', 'it027', 'it028', 'it029', 'it030', 'it031', 'it032', 'it033', 'it034', 'it035', 'it036', 'it037', 'it038', 'it039', 'it040', 'it041', 'it042', 'it043', 'it044', 'it045', 'it046', 'it047', 'it048', 'it049', 'it050', 'it051', 'it052', 'it053', 'it054', 'it055', 'it056', 'it057', 'it058', 'it059', 'it060', 'it061', 'it062', 'it063', 'it064', 'it065', 'it066', 'it067', 'it068', 'it069', 'it070', 'it071', 'it072', 'it073', 'it074', 'it075', 'it076', 'it077', 'it078', 'it079', 'it080', 'it081', 'it082', 'it083', 'it084', 'it085', 'it086', 'it087', 'it088', 'it089', 'it090', 'it091', 'it092', 'it093', 'it094', 'it095', 'it096', 'it097', 'it098', 'it099']>

# %%
ghost_data["it000"]["snapshots"]["snap600"]["gcid"]
# Out:
# <HDF5 dataset "gcid": shape (254,), type "<i8">

# %%
ghost_data.close()
